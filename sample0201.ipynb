# %% [markdown]
# ### 第一個Python 程式

# %%
# print() 方法能將變數顯示出來
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### 認識基本資料型態

# %%
# type 方法能看到類別 (型別)

a = 3 #創建一個整數物件，叫做a，給定值3
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.5
c = "Hello world"

print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### 基本的四則運算

# %%
a = 10
b = 12
c = a + b
print(c)

# 請自己調整加減乘除符號與數值(整數 or 浮點數)
# Out:
# 22

# %%
# 變數本身能自己對自己做加減乘除，習慣上稱之為"更新"
a = 0
print("initial a: ", a)
a = a + 1
print("update a: ", a)
a = a + 1
print("update a: ", a)

# 請自己調整加減乘除符號與數值(整數 or 浮點數)
# Out:
# initial a:  0
# update a:  1
# update a:  2
