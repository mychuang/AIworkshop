# %% [markdown]
# ### 引入資料

# %%
import numpy as np
x1 = np.random.rand(500)
x2 = np.random.rand(500)+1
x3 = np.random.rand(500)+2
x_train = np.concatenate([x1, x2, x3])
x_train = x_train.reshape((1500,1))
print(x_train.shape)

y1 = np.zeros(500, dtype=int)
y2 = np.ones(500, dtype=int)
y3 = np.ones(500, dtype=int)+1
y_train = np.concatenate([y1, y2, y3])

import tensorflow as tf
y_train2 = tf.keras.utils.to_categorical(y_train)

print(y_train2.shape)
# Out:
# (1500, 1)
# (1500, 3)

# %%
"""
activation: https://keras.io/zh/activations/
"""
model = tf.keras.Sequential()
# input layer: 50個神經元, 激活函數使用relu, 輸入一維資料
model.add(tf.keras.layers.Dense(units=50,activation=tf.nn.relu,input_dim=1))
# hidden layer: 10個神經元, 激活函數使用relu
model.add(tf.keras.layers.Dense(units=10,activation=tf.nn.relu))
# output layer: 3個神經元(代表3個結果), 激活函數使用softmax
model.add(tf.keras.layers.Dense(units=3,activation=tf.nn.softmax))

"""
optimizaer: https://keras.io/zh/optimizers/
metrics: https://keras.io/zh/metrics/
loss: https://keras.io/zh/losses/
"""
#model.compile(optimizer='adam',
#       loss = tf.keras.losses.categorical_crossentropy,
#       metrics=['accuracy'])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
    loss = tf.keras.losses.categorical_crossentropy,
    metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ### 訓練模型

# %%
model.fit(x_train,y_train2,
     epochs=20,
     batch_size=128)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 2ms/step - loss: 1.0939 - accuracy: 0.2973
# Epoch 2/20
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0587 - accuracy: 0.3333
# Epoch 3/20
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0324 - accuracy: 0.3627
# Epoch 4/20
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0048 - accuracy: 0.4760
# Epoch 5/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9765 - accuracy: 0.5353
# Epoch 6/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9466 - accuracy: 0.5847
# Epoch 7/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9162 - accuracy: 0.6200
# Epoch 8/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8842 - accuracy: 0.6600
# Epoch 9/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8521 - accuracy: 0.6740
# Epoch 10/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8185 - accuracy: 0.7180
# Epoch 11/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7844 - accuracy: 0.7460
# Epoch 12/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.7713
# Epoch 13/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7161 - accuracy: 0.8167
# Epoch 14/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6816 - accuracy: 0.8187
# Epoch 15/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6477 - accuracy: 0.8573
# Epoch 16/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6151 - accuracy: 0.8700
# Epoch 17/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5833 - accuracy: 0.8740
# Epoch 18/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5539 - accuracy: 0.8960
# Epoch 19/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.8847
# Epoch 20/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.9047

# %% [markdown]
# ### 評估正確率

# %%
x_test = np.array([0.22, 1.31, 2.82])
y_test = np.array([0, 1, 2])
y_test2 = tf.keras.utils.to_categorical(y_test, num_classes=3)
score = model.evaluate(x_test, y_test2, batch_size=128)
print("score:",score)
# Out:
# 1/1 [==============================] - 0s 174ms/step - loss: 0.2195 - accuracy: 1.0000
# score: [0.21946470439434052, 1.0]

# %%
x_test = np.array([0.29,1.61,2.02,2.88])

predict = model.predict(x_test)

print("第一個測試資料:", x_test[0])
print("0 機率:",predict[0][0])
print("1 機率:",predict[0][1])
print("2 機率:",predict[0][2])
print("Ans:",np.argmax(predict[0])) # np.argmax() 返回最大值索引號

print("----------------------------------")

print("第二個測試資料:", x_test[1])
print("0 機率:",predict[1][0])
print("1 機率:",predict[1][1])
print("2 機率:",predict[1][2])
print("Ans:",np.argmax(predict[1])) # np.argmax() 返回最大值索引號

print("----------------------------------")

print("第三個測試資料:", x_test[2])
print("0 機率:",predict[2][0])
print("1 機率:",predict[2][1])
print("2 機率:",predict[2][2])
print("Ans:",np.argmax(predict[2])) # np.argmax() 返回最大值索引號

print("----------------------------------")

print("第四個測試資料:", x_test[3])
print("0 機率:",predict[3][0])
print("1 機率:",predict[3][1])
print("2 機率:",predict[3][2])
print("Ans:",np.argmax(predict[3])) # np.argmax() 返回最大值索引號
# Out:
# 第一個測試資料: 0.29
# 0 機率: 0.88029385
# 1 機率: 0.09920761
# 2 機率: 0.020498533
# Ans: 0
# ----------------------------------
# 第二個測試資料: 1.61
# 0 機率: 0.04982803
# 1 機率: 0.6025934
# 2 機率: 0.3475786
# Ans: 1
# ----------------------------------
# 第三個測試資料: 2.02
# 0 機率: 0.008832963
# 1 機率: 0.38106412
# 2 機率: 0.61010283
# Ans: 2
# ----------------------------------
# 第四個測試資料: 2.88
# 0 機率: 0.00011126376
# 1 機率: 0.068779305
# 2 機率: 0.9311094
# Ans: 2
