# %% [markdown]
# ### 引入資料

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# pandas 模組可以直接處理excell檔案
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/colabData/weather.csv')
print(data.head(5))
print("=================================================================")
print(data.columns)
# Out:
#    MinTemp  MaxTemp  Rainfall  ...  Label  RISK_MM RainTomorrow
# 0      8.0     24.3       0.0  ...      0      3.6          Yes
# 1     14.0     26.9       3.6  ...      1      3.6          Yes
# 2     13.7     23.4       3.6  ...      1     39.8          Yes
# 3     13.3     15.5      39.8  ...      1      2.8          Yes
# 4      7.6     16.1       2.8  ...      1      0.0           No
#
# [5 rows x 23 columns]
# =================================================================
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'Label', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# ### 說明: Pandas 轉 numpy array

# %%
# Look the follwing sample
x1 = data["MinTemp"] # 提供column name 作為data 的索引
print(type(x1)) # 資料型態仍為pandas

import numpy as np # numpy 可參考 AIworkshop-sample0205 範例
x1 = np.array(x1, dtype='float64') #numpy 可直接接收 pandas series 
print(type(x1))
print(x1[:5])

x1 = x1.reshape((x1.shape[0],1)) # 類似 AIworkshop-sample0401 範例，轉成2維矩陣
print(x1[:5])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'numpy.ndarray'>
# [ 8.  14.  13.7 13.3  7.6]
# [[ 8. ]
#  [14. ]
#  [13.7]
#  [13.3]
#  [ 7.6]]

# %%
# 試著讀取其他數據
import numpy as np
x2 = np.array(data["MaxTemp"], dtype='float64')
x2 = x2.reshape((x2.shape[0],1))
print(x2[:5])
# Out:
# [[24.3]
#  [26.9]
#  [23.4]
#  [15.5]
#  [16.1]]

# %%
# 試著合併x1 & x2
x = np.concatenate([x1, x2], axis=1)
print(x[:5])
# Out:
# [[ 8.  24.3]
#  [14.  26.9]
#  [13.7 23.4]
#  [13.3 15.5]
#  [ 7.6 16.1]]

# %% [markdown]
# ### 將pandas 轉 Numpy array

# %%
import numpy as np

# 做出第一個特徵的矩陣
x = np.array(data["MinTemp"], dtype='float64')
x = x.reshape((x.shape[0],1))

# 做出第二個特徵的矩陣，暫存在tempArray，並與x_train合併
tempArray = np.array(data["MaxTemp"], dtype='float64')
tempArray = tempArray.reshape((tempArray.shape[0],1))
x = np.concatenate([x, tempArray], axis=1)

# 做出第三個特徵的矩陣，暫存在tempArray，並與x_train合併
tempArray = np.array(data["Pressure3pm"], dtype='float64')
tempArray = tempArray.reshape((tempArray.shape[0],1))
x = np.concatenate([x, tempArray], axis=1)

# 做出第四個特徵的矩陣，暫存在tempArray，並與x_train合併
tempArray = np.array(data["Pressure9am"], dtype='float64')
tempArray = tempArray.reshape((tempArray.shape[0],1))
x = np.concatenate([x, tempArray], axis=1)

print(x[:5])
# Out:
# [[   8.    24.3 1015.  1019.7]
#  [  14.    26.9 1008.4 1012.4]
#  [  13.7   23.4 1007.2 1009.5]
#  [  13.3   15.5 1007.  1005.5]
#  [   7.6   16.1 1018.5 1018.3]]

# %%
y = np.array(data["Label"], dtype='int64')
y = y.reshape((y.shape[0],1))
print(y[:5])
# Out:
# [[0]
#  [1]
#  [1]
#  [1]
#  [1]]

# %% [markdown]
# ### 產出測試集與訓練集

# %%
from sklearn.model_selection import train_test_split

print(x.shape)
print(y.shape)
x_train , x_test , y_train , y_test = train_test_split(x, y, test_size=0.05)

print(x_test.shape)
print(y_test.shape)
# Out:
# (356, 4)
# (356, 1)
# (18, 4)
# (18, 1)

# %% [markdown]
# ### 將Label資料轉成單熱編碼

# %%
import tensorflow as tf
y_train2 = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test2 = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %% [markdown]
# ### 建立模型

# %%
"""
activation: https://keras.io/zh/activations/
"""
model = tf.keras.Sequential()
# input layer: 50個神經元, 激活函數使用relu, 輸入4維資料
model.add(tf.keras.layers.Dense(units=50,activation=tf.nn.relu,input_dim=4))
# hidden layer: 50個神經元, 激活函數使用relu
model.add(tf.keras.layers.Dense(units=50,activation=tf.nn.relu))
# output layer: 2個神經元(代表兩個結果), 激活函數使用softmax
model.add(tf.keras.layers.Dense(units=2,activation=tf.nn.softmax ))

"""
optimizaer: https://keras.io/zh/optimizers/
metrics: https://keras.io/zh/metrics/
loss: https://keras.io/zh/losses/
"""

#model.compile(optimizer='adam',
#       loss = tf.keras.losses.categorical_crossentropy,
#       metrics=['accuracy'])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
    loss = tf.keras.losses.categorical_crossentropy,
    metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# ### 訓練模型

# %%
history = model.fit(x_train, y_train2, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 3ms/step - loss: 38.1908 - accuracy: 0.8225
# Epoch 2/100
# 6/6 [==============================] - 0s 4ms/step - loss: 3.5785 - accuracy: 0.5799
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 3.7460 - accuracy: 0.7840
# Epoch 4/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4422 - accuracy: 0.7485
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.3909 - accuracy: 0.6746
# Epoch 6/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.8599 - accuracy: 0.6302
# Epoch 7/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2.3295 - accuracy: 0.7929
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2.5317 - accuracy: 0.7278
# Epoch 9/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.6531 - accuracy: 0.5917
# Epoch 10/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2.3509 - accuracy: 0.8195
# Epoch 11/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.5822 - accuracy: 0.6864
# Epoch 12/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9598 - accuracy: 0.7071
# Epoch 13/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9822 - accuracy: 0.7308
# Epoch 14/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8735 - accuracy: 0.7160
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7259 - accuracy: 0.7337
# Epoch 16/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5435 - accuracy: 0.7663
# Epoch 17/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8125 - accuracy: 0.7456
# Epoch 18/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7266 - accuracy: 0.7308
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5725 - accuracy: 0.7811
# Epoch 20/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6258 - accuracy: 0.7604
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9870 - accuracy: 0.7278
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2551 - accuracy: 0.7041
# Epoch 23/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0648 - accuracy: 0.7071
# Epoch 24/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.5441 - accuracy: 0.6982
# Epoch 25/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.3186 - accuracy: 0.6746
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4827 - accuracy: 0.6538
# Epoch 27/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.3270 - accuracy: 0.6509
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.4615 - accuracy: 0.6864
# Epoch 29/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4092 - accuracy: 0.7012
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9687 - accuracy: 0.7929
# Epoch 31/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8038 - accuracy: 0.7308
# Epoch 32/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8649 - accuracy: 0.7722
# Epoch 33/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9825 - accuracy: 0.6746
# Epoch 34/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9458 - accuracy: 0.7367
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7159 - accuracy: 0.7633
# Epoch 36/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5108 - accuracy: 0.8047
# Epoch 37/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5224 - accuracy: 0.7633
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6347 - accuracy: 0.7633
# Epoch 39/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6780 - accuracy: 0.7840
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5504 - accuracy: 0.7426
# Epoch 41/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.1764 - accuracy: 0.7692
# Epoch 42/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.5119 - accuracy: 0.8136
# Epoch 43/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.4226 - accuracy: 0.7041
# Epoch 44/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.9399 - accuracy: 0.7130
# Epoch 45/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0239 - accuracy: 0.7071
# Epoch 46/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.9414 - accuracy: 0.6746
# Epoch 47/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.1386 - accuracy: 0.6775
# Epoch 48/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2785 - accuracy: 0.7130
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.7189
# Epoch 50/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6382 - accuracy: 0.7485
# Epoch 51/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6458 - accuracy: 0.7781
# Epoch 52/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4671 - accuracy: 0.8166
# Epoch 53/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4719 - accuracy: 0.8018
# Epoch 54/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5156 - accuracy: 0.7811
# Epoch 55/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7282 - accuracy: 0.7160
# Epoch 56/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6251 - accuracy: 0.7722
# Epoch 57/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.7692
# Epoch 58/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6295 - accuracy: 0.7515
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9296 - accuracy: 0.6834
# Epoch 60/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7699 - accuracy: 0.7574
# Epoch 61/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.7840
# Epoch 62/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5777 - accuracy: 0.7633
# Epoch 63/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.0268 - accuracy: 0.6923
# Epoch 64/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.9292 - accuracy: 0.8225
# Epoch 65/100
# 6/6 [==============================] - 0s 3ms/step - loss: 3.0008 - accuracy: 0.6243
# Epoch 66/100
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3591 - accuracy: 0.5680
# Epoch 67/100
# 6/6 [==============================] - 0s 3ms/step - loss: 3.6125 - accuracy: 0.8225
# Epoch 68/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7200 - accuracy: 0.5740
# Epoch 69/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4.2182 - accuracy: 0.8225
# Epoch 70/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4181 - accuracy: 0.7101
# Epoch 71/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.8661 - accuracy: 0.6805
# Epoch 72/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2.0270 - accuracy: 0.8225
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.2400 - accuracy: 0.6657
# Epoch 74/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.9478 - accuracy: 0.6923
# Epoch 75/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.9758 - accuracy: 0.7870
# Epoch 76/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2734 - accuracy: 0.8077
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6728 - accuracy: 0.7929
# Epoch 78/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7265 - accuracy: 0.7959
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2701 - accuracy: 0.8107
# Epoch 80/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6705 - accuracy: 0.7574
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8210 - accuracy: 0.7959
# Epoch 82/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1.2981 - accuracy: 0.7870
# Epoch 83/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8921 - accuracy: 0.7959
# Epoch 84/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8588 - accuracy: 0.6923
# Epoch 85/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1.0479 - accuracy: 0.7249
# Epoch 86/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5691 - accuracy: 0.7988
# Epoch 87/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4530 - accuracy: 0.8047
# Epoch 88/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5414 - accuracy: 0.7781
# Epoch 89/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8225
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4992 - accuracy: 0.7870
# Epoch 91/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5508 - accuracy: 0.7692
# Epoch 92/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5145 - accuracy: 0.7840
# Epoch 93/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.8077
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.7899
# Epoch 95/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8173 - accuracy: 0.7456
# Epoch 96/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6060 - accuracy: 0.7959
# Epoch 97/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4419 - accuracy: 0.8107
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4215 - accuracy: 0.8195
# Epoch 99/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4167 - accuracy: 0.8225
# Epoch 100/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4671 - accuracy: 0.7929

# %% [markdown]
# ### 評估模型

# %%
score = model.evaluate(x_test, y_test2)
print("score:",score)
# Out:
# 1/1 [==============================] - 0s 142ms/step - loss: 0.4882 - accuracy: 0.7778
# score: [0.48818185925483704, 0.7777777910232544]

# %%
loss = np.array(history.history['loss'], dtype='float64')
loss = loss/max(loss)

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(loss)
plt.title('model accuracy')
plt.ylabel('acc & loss')
plt.xlabel('epoch')
plt.legend(['acc', 'loss'], loc='upper left')
plt.show()

# %% [markdown]
# ### 預測

# %%
predict = model.predict(x_test)

print("第一個測試資料:", x_test[0])
print("不下雨 機率:",predict[0][0])
print("下雨 機率:",predict[0][1])
if(np.argmax(predict[0]) == 0):
  print("預測; 不下雨")
else:
  print("預測: 下雨")
  
print(y_test2[0])
# Out:
# 第一個測試資料: [   9.2   20.4 1009.1 1009.5]
# 不下雨 機率: 0.91890424
# 下雨 機率: 0.08109576
# 預測; 不下雨
# [0. 1.]
